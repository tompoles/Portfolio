# %% [markdown]
# <a href="https://colab.research.google.com/github/tompoles/Portfolio/blob/project_3/Cars_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from termcolor import colored as cl
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/MyDrive/Colab_Notebooks
# Out:
# Mounted at /gdrive
# /gdrive/MyDrive/Colab_Notebooks

# %%
df = pd.read_csv('/gdrive/MyDrive/Colab Notebooks/carsdata.csv')
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df = df.drop_duplicates()
# Out:
#           Make       Model  Year  ... city mpg  Popularity   MSRP
# 0          BMW  1 Series M  2011  ...       19        3916  46135
# 1          BMW    1 Series  2011  ...       19        3916  40650
# 2          BMW    1 Series  2011  ...       20        3916  36350
# 3          BMW    1 Series  2011  ...       18        3916  29450
# 4          BMW    1 Series  2011  ...       18        3916  34500
# ...        ...         ...   ...  ...      ...         ...    ...
# 11909    Acura         ZDX  2012  ...       16         204  46120
# 11910    Acura         ZDX  2012  ...       16         204  56670
# 11911    Acura         ZDX  2012  ...       16         204  50620
# 11912    Acura         ZDX  2013  ...       16         204  50920
# 11913  Lincoln      Zephyr  2006  ...       17          61  28995
#
# [11199 rows x 16 columns]

# %%
df.count()
print(df.isnull().sum())
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3376
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df = df.dropna()
df.describe()
df = df.rename(columns=({'MSRP':'Price'}))

# %%
print(df.isnull().sum())

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3-Q1
print(IQR)
# Out:
# Year                    6.0
# Engine HP             131.0
# Engine Cylinders        2.0
# Number of Doors         2.0
# highway MPG             8.0
# city mpg                6.0
# Popularity           1489.0
# Price               23252.5
# dtype: float64

# %%
sns.boxplot(x=df['Price'])

# %%
df = df[~((df < (Q1-1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# (5622, 16)

# %%
df.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title('Number of cars by make')
plt.ylabel('Number of cars')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
# Finding the relations between the variables.
plt.figure(figsize=(20,10))
c= df.corr()
sns.heatmap(c,cmap='BrBG',annot=True)
c
# Out:
#                       Year  Engine HP  ...  Popularity     Price
# Year              1.000000   0.151051  ...    0.194030  0.224195
# Engine HP         0.151051   1.000000  ...    0.089515  0.757838
# Engine Cylinders -0.173957   0.772090  ...    0.021924  0.518301
# Number of Doors   0.121819  -0.038800  ...   -0.098174  0.015691
# highway MPG       0.344971  -0.558102  ...    0.109159 -0.308098
# city mpg          0.320515  -0.646821  ...    0.062135 -0.381777
# Popularity        0.194030   0.089515  ...    1.000000  0.141315
# Price             0.224195   0.757838  ...    0.141315  1.000000
#
# [8 rows x 8 columns]

# %%
IQR['Price']
# Out:
# 23252.5

# %%
# Plotting a scatter plot
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Engine HP'], df['Price'], alpha=0.1)
ax.set_xlabel('Engine HP')
ax.set_ylabel('Price')
plt.show()
